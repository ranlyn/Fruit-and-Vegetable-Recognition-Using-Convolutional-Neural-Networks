# %% [markdown]
# <a href="https://colab.research.google.com/github/ranlyn/Fruit-and-Vegetable-Recognition-Using-Convolutional-Neural-Networks/blob/main/TestingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
#connect to drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cnn = tf.keras.models.load_model("/content/drive/MyDrive/trained_model.h5")

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
'/content/drive/MyDrive/Fruit and vegetables dataset/test',
    labels='inferred',
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64,64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
nutritional_values = {
    "apple": {
        "calories": 52,
        "carbs(g)": 14,
        "fiber(g)": 2.4,
        "sugars(g)": 10,
        "protein(g)": 0.3,
        "fat(g)": 0.2,
        "vitamin C(mg)": 5,
        "potassium(mg)": 107,
        "magnesium(mg)": 5,
        "phosphorus(mg)": 11,
        "calcium(mg)": 6,
        "iron(mg)": 0.1,
        "zinc(mg)": 0.05,
        "copper(mg)": 0.03,
        "manganese(mg)": 0.1,
        "folate(µg)": 4,
        "choline(mg)": 4.4
    },
    "banana": {
        "calories": 89,
        "carbs(g)": 23,
        "fiber(g)": 2.6,
        "sugars(g)": 12,
        "protein(g)": 1.3,
        "fat(g)": 0.3,
        "vitamin C(mg)": 10,
        "potassium(mg)": 422,
        "magnesium(mg)": 32,
        "phosphorus(mg)": 29,
        "calcium(mg)": 5,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 23,
        "choline(mg)": 12.5
    },
    "beetroot": {
        "calories": 43,
        "carbs(g)": 10,
        "fiber(g)": 2,
        "sugars(g)": 7,
        "protein(g)": 1.6,
        "fat(g)": 0.2,
        "vitamin C(mg)": 4,
        "potassium(mg)": 325,
        "magnesium(mg)": 23,
        "phosphorus(mg)": 40,
        "calcium(mg)": 16,
        "iron(mg)": 0.8,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 109,
        "choline(mg)": 8.7
    },
    "bell pepper": {
        "calories": 31,
        "carbs(g)": 6,
        "fiber(g)": 2.1,
        "sugars(g)": 4.2,
        "protein(g)": 1.3,
        "fat(g)": 0.3,
        "vitamin C(mg)": 80,
        "potassium(mg)": 175,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 26,
        "calcium(mg)": 10,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 18,
        "choline(mg)": 7.8
    },
    "cabbage": {
        "calories": 25,
        "carbs(g)": 6,
        "fiber(g)": 2.5,
        "sugars(g)": 3.2,
        "protein(g)": 1.3,
        "fat(g)": 0.1,
        "vitamin C(mg)": 36,
        "potassium(mg)": 170,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 26,
        "calcium(mg)": 40,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 43,
        "choline(mg)": 15.5
    },
    "capsicum": {
        "calories": 20,
        "carbs(g)": 4.7,
        "fiber(g)": 1.7,
        "sugars(g)": 2.3,
        "protein(g)": 0.9,
        "fat(g)": 0.2,
        "vitamin C(mg)": 80,
        "potassium(mg)": 173,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 20,
        "calcium(mg)": 8,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 10,
        "choline(mg)": 5.7
    },
    "carrot": {
        "calories": 41,
        "carbs(g)": 10,
        "fiber(g)": 2.8,
        "sugars(g)": 4.7,
        "protein(g)": 0.9,
        "fat(g)": 0.2,
        "vitamin C(mg)": 6,
        "potassium(mg)": 320,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 35,
        "calcium(mg)": 33,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 19,
        "choline(mg)": 6.1
    },
    "cauliflower": {
        "calories": 25,
        "carbs(g)": 5,
        "fiber(g)": 2,
        "sugars(g)": 1.9,
        "protein(g)": 1.9,
        "fat(g)": 0.3,
        "vitamin C(mg)": 48,
        "potassium(mg)": 299,
        "magnesium(mg)": 15,
        "phosphorus(mg)": 47,
        "calcium(mg)": 22,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 57,
        "choline(mg)": 44.3
    },
    "chilli pepper": {
        "calories": 40,
        "carbs(g)": 9,
        "fiber(g)": 3.5,
        "sugars(g)": 5.3,
        "protein(g)": 1.9,
        "fat(g)": 0.2,
        "vitamin C(mg)": 144,
        "potassium(mg)": 322,
        "magnesium(mg)": 26,
        "phosphorus(mg)": 43,
        "calcium(mg)": 14,
        "iron(mg)": 0.9,
        "zinc(mg)": 0.4,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 12,
        "choline(mg)": 8.7
    },
    "corn": {
        "calories": 86,
        "carbs(g)": 19,
        "fiber(g)": 2,
        "sugars(g)": 5,
        "protein(g)": 3.2,
        "fat(g)": 1.5,
        "vitamin C(mg)": 6,
        "potassium(mg)": 270,
        "magnesium(mg)": 37,
        "phosphorus(mg)": 89,
        "calcium(mg)": 2,
        "iron(mg)": 0.5,
        "zinc(mg)": 0.9,
        "copper(mg)": 0.2,
        "manganese(mg)": 0.5,
        "folate(µg)": 42,
        "choline(mg)": 15.1
    },
    "cucumber": {
        "calories": 15,
        "carbs(g)": 3.6,
        "fiber(g)": 0.5,
        "sugars(g)": 1.7,
        "protein(g)": 0.7,
        "fat(g)": 0.1,
        "vitamin C(mg)": 2.8,
        "potassium(mg)": 147,
        "magnesium(mg)": 13,
        "phosphorus(mg)": 24,
        "calcium(mg)": 16,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 7,
        "choline(mg)": 5
    },
    "eggplant": {
        "calories": 25,
        "carbs(g)": 6,
        "fiber(g)": 3,
        "sugars(g)": 3.5,
        "protein(g)": 1,
        "fat(g)": 0.2,
        "vitamin C(mg)": 2.2,
        "potassium(mg)": 229,
        "magnesium(mg)": 14,
        "phosphorus(mg)": 24,
        "calcium(mg)": 9,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 22,
        "choline(mg)": 5.9
    },
    "garlic": {
        "calories": 149,
        "carbs(g)": 33,
        "fiber(g)": 2.1,
        "sugars(g)": 1,
        "protein(g)": 6.4,
        "fat(g)": 0.5,
        "vitamin C(mg)": 31,
        "potassium(mg)": 401,
        "magnesium(mg)": 25,
        "phosphorus(mg)": 153,
        "calcium(mg)": 181,
        "iron(mg)": 1.7,
        "zinc(mg)": 1.2,
        "copper(mg)": 0.3,
        "manganese(mg)": 1.7,
        "folate(µg)": 3,
        "choline(mg)": 5.3
    },
    "ginger": {
        "calories": 80,
        "carbs(g)": 18,
        "fiber(g)": 2,
        "sugars(g)": 1.7,
        "protein(g)": 1.8,
        "fat(g)": 0.8,
        "vitamin C(mg)": 0.7,
        "potassium(mg)": 415,
        "magnesium(mg)": 43,
        "phosphorus(mg)": 34,
        "calcium(mg)": 16,
        "iron(mg)": 0.6,
        "zinc(mg)": 0.6,
        "copper(mg)": 0.2,
        "manganese(mg)": 0.2,
        "folate(µg)": 11,
        "choline(mg)": 4.4
    },
    "grapes": {
        "calories": 69,
        "carbs(g)": 18,
        "fiber(g)": 0.9,
        "sugars(g)": 15,
        "protein(g)": 0.7,
        "fat(g)": 0.2,
        "vitamin C(mg)": 4,
        "potassium(mg)": 191,
        "magnesium(mg)": 7,
        "phosphorus(mg)": 20,
        "calcium(mg)": 10,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.2,
        "manganese(mg)": 0.1,
        "folate(µg)": 3,
        "choline(mg)": 6.2
    },
    "jalepeno": {
        "calories": 27,
        "carbs(g)": 6,
        "fiber(g)": 2.8,
        "sugars(g)": 4.1,
        "protein(g)": 0.9,
        "fat(g)": 0.3,
        "vitamin C(mg)": 118,
        "potassium(mg)": 259,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 23,
        "calcium(mg)": 10,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 20,
        "choline(mg)": 5.3
    },
    "kiwi": {
        "calories": 61,
        "carbs(g)": 15,
        "fiber(g)": 3,
        "sugars(g)": 9,
        "protein(g)": 1.1,
        "fat(g)": 0.5,
        "vitamin C(mg)": 93,
        "potassium(mg)": 312,
        "magnesium(mg)": 17,
        "phosphorus(mg)": 34,
        "calcium(mg)": 34,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 25,
        "choline(mg)": 7.8
    },
    "lemon": {
        "calories": 29,
        "carbs(g)": 9,
        "fiber(g)": 2.8,
        "sugars(g)": 2.5,
        "protein(g)": 1.1,
        "fat(g)": 0.3,
        "vitamin C(mg)": 53,
        "potassium(mg)": 138,
        "magnesium(mg)": 8,
        "phosphorus(mg)": 16,
        "calcium(mg)": 26,
        "iron(mg)": 0.6,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 11,
        "choline(mg)": 5.1
    },
    "lettuce": {
        "calories": 15,
        "carbs(g)": 2.9,
        "fiber(g)": 1.3,
        "sugars(g)": 1,
        "protein(g)": 1.4,
        "fat(g)": 0.2,
        "vitamin C(mg)": 4.8,
        "potassium(mg)": 194,
        "magnesium(mg)": 13,
        "phosphorus(mg)": 29,
        "calcium(mg)": 36,
        "iron(mg)": 0.9,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 38,
        "choline(mg)": 6.7
    },
    "mango": {
        "calories": 60,
        "carbs(g)": 15,
        "fiber(g)": 1.6,
        "sugars(g)": 14,
        "protein(g)": 0.8,
        "fat(g)": 0.4,
        "vitamin C(mg)": 36,
        "potassium(mg)": 168,
        "magnesium(mg)": 9,
        "phosphorus(mg)": 11,
        "calcium(mg)": 11,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 14,
        "choline(mg)": 7.6
    },
    "onion": {
        "calories": 40,
        "carbs(g)": 9,
        "fiber(g)": 1.7,
        "sugars(g)": 4.7,
        "protein(g)": 1.1,
        "fat(g)": 0.1,
        "vitamin C(mg)": 7,
        "potassium(mg)": 146,
        "magnesium(mg)": 10,
        "phosphorus(mg)": 29,
        "calcium(mg)": 23,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 19,
        "choline(mg)": 6.5
    },
    "orange": {
        "calories": 47,
        "carbs(g)": 12,
        "fiber(g)": 2.4,
        "sugars(g)": 9,
        "protein(g)": 0.9,
        "fat(g)": 0.1,
        "vitamin C(mg)": 51,
        "potassium(mg)": 181,
        "magnesium(mg)": 10,
        "phosphorus(mg)": 14,
        "calcium(mg)": 40,
        "iron(mg)": 0.1,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 30,
        "choline(mg)": 8.4
    },
    "paprika": {
        "calories": 43,
        "carbs(g)": 10,
        "fiber(g)": 2,
        "sugars(g)": 5.3,
        "protein(g)": 1,
        "fat(g)": 0.5,
        "vitamin C(mg)": 80,
        "potassium(mg)": 175,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 26,
        "calcium(mg)": 10,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.2,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 18,
        "choline(mg)": 7.8
    },
    "pear": {
        "calories": 57,
        "carbs(g)": 15,
        "fiber(g)": 3.1,
        "sugars(g)": 9,
        "protein(g)": 0.4,
        "fat(g)": 0.1,
        "vitamin C(mg)": 4,
        "potassium(mg)": 119,
        "magnesium(mg)": 7,
        "phosphorus(mg)": 12,
        "calcium(mg)": 11,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 7,
        "choline(mg)": 4.7
    },
    "peas": {
        "calories": 81,
        "carbs(g)": 14,
        "fiber(g)": 5.7,
        "sugars(g)": 5.7,
        "protein(g)": 5,
        "fat(g)": 0.4,
        "vitamin C(mg)": 40,
        "potassium(mg)": 244,
        "magnesium(mg)": 33,
        "phosphorus(mg)": 108,
        "calcium(mg)": 25,
        "iron(mg)": 2.1,
        "zinc(mg)": 1.2,
        "copper(mg)": 0.3,
        "manganese(mg)": 0.5,
        "folate(µg)": 65,
        "choline(mg)": 24.8
    },
    "pineapple": {
        "calories": 50,
        "carbs(g)": 13,
        "fiber(g)": 1.4,
        "sugars(g)": 10,
        "protein(g)": 0.5,
        "fat(g)": 0.1,
        "vitamin C(mg)": 47,
        "potassium(mg)": 109,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 13,
        "calcium(mg)": 13,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 18,
        "choline(mg)": 7.7
    },
    "pomegranate": {
        "calories": 83,
        "carbs(g)": 18,
        "fiber(g)": 4,
        "sugars(g)": 13,
        "protein(g)": 1.7,
        "fat(g)": 1.2,
        "vitamin C(mg)": 10,
        "potassium(mg)": 236,
        "magnesium(mg)": 12,
        "phosphorus(mg)": 36,
        "calcium(mg)": 10,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.3,
        "manganese(mg)": 0.4,
        "folate(µg)": 38,
        "choline(mg)": 7.6
    },
    "potato": {
        "calories": 77,
        "carbs(g)": 17,
        "fiber(g)": 2.2,
        "sugars(g)": 0.8,
        "protein(g)": 2,
        "fat(g)": 0.1,
        "vitamin C(mg)": 20,
        "potassium(mg)": 425,
        "magnesium(mg)": 23,
        "phosphorus(mg)": 57,
        "calcium(mg)": 12,
        "iron(mg)": 0.8,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 17,
        "choline(mg)": 12.2
    },
    "raddish": {
        "calories": 16,
        "carbs(g)": 4,
        "fiber(g)": 1.6,
        "sugars(g)": 2.2,
        "protein(g)": 0.7,
        "fat(g)": 0.1,
        "vitamin C(mg)": 25,
        "potassium(mg)": 233,
        "magnesium(mg)": 10,
        "phosphorus(mg)": 20,
        "calcium(mg)": 25,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 25,
        "choline(mg)": 8.1
    },
    "soy beans": {
        "calories": 446,
        "carbs(g)": 30,
        "fiber(g)": 9,
        "sugars(g)": 7,
        "protein(g)": 36,
        "fat(g)": 20,
        "vitamin C(mg)": 6,
        "potassium(mg)": 1797,
        "magnesium(mg)": 280,
        "phosphorus(mg)": 704,
        "calcium(mg)": 277,
        "iron(mg)": 15.7,
        "zinc(mg)": 4.9,
        "copper(mg)": 2.2,
        "manganese(mg)": 2.5,
        "folate(µg)": 375,
        "choline(mg)": 187
    },
    "spinach": {
        "calories": 23,
        "carbs(g)": 4,
        "fiber(g)": 2.2,
        "sugars(g)": 0.4,
        "protein(g)": 2.9,
        "fat(g)": 0.4,
        "vitamin C(mg)": 28,
        "potassium(mg)": 558,
        "magnesium(mg)": 79,
        "phosphorus(mg)": 49,
        "calcium(mg)": 99,
        "iron(mg)": 2.7,
        "zinc(mg)": 0.5,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.9,
        "folate(µg)": 194,
        "choline(mg)": 19.7
    },
    "sweetcorn": {
        "calories": 86,
        "carbs(g)": 19,
        "fiber(g)": 2,
        "sugars(g)": 5,
        "protein(g)": 3.2,
        "fat(g)": 1.5,
        "vitamin C(mg)": 6,
        "potassium(mg)": 270,
        "magnesium(mg)": 37,
        "phosphorus(mg)": 89,
        "calcium(mg)": 2,
        "iron(mg)": 0.5,
        "zinc(mg)": 0.9,
        "copper(mg)": 0.2,
        "manganese(mg)": 0.5,
        "folate(µg)": 42,
        "choline(mg)": 15.1
    },
    "sweetpotato": {
        "calories": 86,
        "carbs(g)": 20,
        "fiber(g)": 3,
        "sugars(g)": 4.2,
        "protein(g)": 1.6,
        "fat(g)": 0.1,
        "vitamin C(mg)": 2.4,
        "potassium(mg)": 337,
        "magnesium(mg)": 23,
        "phosphorus(mg)": 38,
        "calcium(mg)": 30,
        "iron(mg)": 0.8,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.3,
        "folate(µg)": 11,
        "choline(mg)": 10.8
    },
    "tomato": {
        "calories": 18,
        "carbs(g)": 4,
        "fiber(g)": 1.2,
        "sugars(g)": 2.6,
        "protein(g)": 0.9,
        "fat(g)": 0.2,
        "vitamin C(mg)": 14,
        "potassium(mg)": 237,
        "magnesium(mg)": 11,
        "phosphorus(mg)": 24,
        "calcium(mg)": 10,
        "iron(mg)": 0.3,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 6,
        "choline(mg)": 4.8
    },
    "watermelon": {
        "calories": 30,
        "carbs(g)": 8,
        "fiber(g)": 0.4,
        "sugars(g)": 6,
        "protein(g)": 0.6,
        "fat(g)": 0.2,
        "vitamin C(mg)": 8.1,
        "potassium(mg)": 112,
        "magnesium(mg)": 10,
        "phosphorus(mg)": 11,
        "calcium(mg)": 7,
        "iron(mg)": 0.2,
        "zinc(mg)": 0.1,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.1,
        "folate(µg)": 3,
        "choline(mg)": 4.1
    },
    "zucchini": {
        "calories": 17,
        "carbs(g)": 3.1,
        "fiber(g)": 1,
        "sugars(g)": 2.1,
        "protein(g)": 1.2,
        "fat(g)": 0.3,
        "vitamin C(mg)": 17,
        "potassium(mg)": 261,
        "magnesium(mg)": 18,
        "phosphorus(mg)": 38,
        "calcium(mg)": 16,
        "iron(mg)": 0.4,
        "zinc(mg)": 0.3,
        "copper(mg)": 0.1,
        "manganese(mg)": 0.2,
        "folate(µg)": 24,
        "choline(mg)": 9.5
    }
}

# %%
# List of fruits and vegetables
fruits = ['apple', 'banana', 'beetroot', 'bell pepper', 'cabbage', 'capsicum', 'carrot', 'cauliflower', 'chilli pepper', 'corn', 'cucumber', 'eggplant', 'garlic', 'ginger', 'grapes', 'jalepeno', 'kiwi', 'lemon', 'lettuce', 'mango', 'onion', 'orange', 'paprika', 'pear', 'peas', 'pineapple', 'pomegranate', 'potato', 'raddish', 'soy beans', 'spinach', 'sweetcorn', 'sweetpotato', 'tomato', 'turnip', 'watermelon']

# Classify fruits and vegetables
classification_dict = {}
for item in fruits:
    if item in ['apple', 'banana', 'grapes', 'kiwi', 'lemon', 'mango', 'orange', 'paprika', 'pear', 'pineapple', 'pomegranate', 'watermelon']:
        classification_dict[item] = 'Fruit'
    else:
        classification_dict[item] = 'Vegetable'

# Print the classification dictionary
print(classification_dict)
# Out:
# {'apple': 'Fruit', 'banana': 'Fruit', 'beetroot': 'Vegetable', 'bell pepper': 'Vegetable', 'cabbage': 'Vegetable', 'capsicum': 'Vegetable', 'carrot': 'Vegetable', 'cauliflower': 'Vegetable', 'chilli pepper': 'Vegetable', 'corn': 'Vegetable', 'cucumber': 'Vegetable', 'eggplant': 'Vegetable', 'garlic': 'Vegetable', 'ginger': 'Vegetable', 'grapes': 'Fruit', 'jalepeno': 'Vegetable', 'kiwi': 'Fruit', 'lemon': 'Fruit', 'lettuce': 'Vegetable', 'mango': 'Fruit', 'onion': 'Vegetable', 'orange': 'Fruit', 'paprika': 'Fruit', 'pear': 'Fruit', 'peas': 'Vegetable', 'pineapple': 'Fruit', 'pomegranate': 'Fruit', 'potato': 'Vegetable', 'raddish': 'Vegetable', 'soy beans': 'Vegetable', 'spinach': 'Vegetable', 'sweetcorn': 'Vegetable', 'sweetpotato': 'Vegetable', 'tomato': 'Vegetable', 'turnip': 'Vegetable', 'watermelon': 'Fruit'}

# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# Load the original image
image_path = input("Enter the image path: ")
img = cv2.imread(image_path)

# Load and preprocess the image for prediction
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(64, 64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to batch

# Make predictions
predictions = cnn.predict(input_arr)

# Get the predicted class index
result_index = np.argmax(predictions)

# Get the predicted class and category
predicted_class = test_set.class_names[result_index]
category = classification_dict.get(predicted_class, "Unknown")

# Display the original image and nutritional value box
fig, axs = plt.subplots(1, 2, figsize=(10, 6))

# Display the nutritional values on the right side with a title
nutritional_values_box = "\n".join([f"{nutrient}: {value}" for nutrient, value in nutritional_values[predicted_class].items()])
axs[1].text(0.5, 0.9, "Nutritional Values", fontsize=12, horizontalalignment='center')
axs[1].text(0.5, 0.5, nutritional_values_box, fontsize=12, bbox=dict(facecolor='white', alpha=0.5), verticalalignment='center', horizontalalignment='center')
axs[1].axis('off')

# Display the image on the left
axs[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axs[0].set_title(f"Predicted class: {predicted_class}\nCategory: {category}", fontsize=12, horizontalalignment='center')
axs[0].set_xticks([])
axs[0].set_yticks([])

plt.show()
# Out:
# Enter the image path: /content/drive/MyDrive/Fruit and vegetables dataset/test/apple/Image_1.jpg
# 1/1 [==============================] - 0s 354ms/step
